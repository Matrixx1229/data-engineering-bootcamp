# %% [markdown]
# # Objects and Classes

# %%
class employee():

  emp_name = 'Rahul'
  emp_dept = 'IT'
  
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept}")
    
emp1 = employee()
print(emp1.emp_name)
print(emp1.emp_dept)
print(emp1.info())

# %%
class employee():

  emp_name = 'Rahul'
  emp_dept = 'IT'
  
  def info(self,emp_name, emp_dept):
    print(f"Employee {emp_name} works for {emp_dept}")
    
emp1 = employee()
emp1.info("onkar" , "IT")

# %%
# constructor

class employee():

  company_name = 'XYS' 
  def __init__(self, emp_name, emp_dept):
    self.emp_name = emp_name
    self.emp_dept = emp_dept
  
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept}")
    
emp1 = employee("onkar" , "IT")
emp2 = employee("Rahul" , "IT")
# print(emp1.company_name)
# print(emp2.company_name)
# print(emp1.emp_name)
# print(emp1.emp_dept)
emp1.info()
print(emp1.company_name)
emp2.info()
print(emp2.company_name)

# %%
class employee():

  company_name = 'XYS' 
  def __init__(self, emp_name, emp_dept):
    self.emp_name = emp_name
    self.emp_dept = emp_dept
  
  def changes(self, new_company):
    employee.company_name = new_company
  
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept} in {self.company_name}")
    
emp1 = employee("onkar" , "IT")
emp2 = employee("Rahul" , "IT")

# employee.company_name = "ABC"

# emp1.info()

emp1.changes("new company")

emp2.info()

# %%
class employee():

  company_name = 'XYS' 
  def __init__(self, emp_name, emp_dept):
    self.emp_name = emp_name
    self.emp_dept = emp_dept
  
  def changes(self, new_company):
    employee.company_name = new_company
  
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept} in {self.company_name}")
  
  @staticmethod
  def addition(x,y):
      print(x+y)
    
emp1 = employee("onkar" , "IT")
emp2 = employee("Rahul" , "IT")

# employee.company_name = "ABC"

# emp1.info()

# emp1.changes("new company")

# emp2.info()

emp1.addition(1,2)

# %%
class employee():

  company_name = 'XYS' 
  def __init__(self, emp_name, emp_dept):
    self.emp_name = emp_name
    self.emp_dept = emp_dept
  
  def changes(self, new_company):
    employee.company_name = new_company
  
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept} in {self.company_name}")
  
  @staticmethod
  def addition(x,y):
      print(x+y)

  @classmethod
  def chnageInClass(cls, new_company):
      cls.company_name = new_company
    
emp1 = employee("onkar" , "IT")
emp2 = employee("Rahul" , "IT")

emp1.chnageInClass("newnew company")

print(emp1.company_name)
# emp1.addition(1,2)

# %% [markdown]
# ## getters and setters

# %%
class employee():

  company_name = 'XYS' 
  def __init__(self, emp_name, emp_dept):
    self.emp_name = emp_name
    self.emp_dept = emp_dept
  
  def changes(self, new_company):
    employee.company_name = new_company
  
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept} in {self.company_name}")

  def changeinfo(self, new_empname, new_empdept):
      self.emp_name = new_empname
      self.emp_dept = new_empdept
  
  @staticmethod
  def addition(x,y):
      print(x+y)

  @classmethod
  def chnageInClass(cls, new_company):
      cls.company_name = new_company
    
emp1 = employee("onkar" , "IT")

emp1.info()
emp1.changeinfo("Priyaa", "HR")
emp1.info()
# emp2 = employee("Rahul" , "IT")

# # emp1.chnageInClass("newnew company")

# print(emp1.company_name)
# # emp1.addition(1,2)

# %%
class employee():

  company_name = 'XYS' 
  def __init__(self, emp_name, emp_dept):
    self.emp_name = emp_name
    self.emp_dept = emp_dept
  
  def changes(self, new_company):
    employee.company_name = new_company
  
  @property #getter 
  def info(self):
    print(f"Employee {self.emp_name} works for {self.emp_dept} in {self.company_name}")

#   @info.setter()
#   def info(self, new_empname, new_empdept):
#     self.emp_name = new_empname
#     self.emp_dept = new_empdept
  @info.setter
  def info(self, new_empdetails):
    new_empname = new_empdetails[0]
    new_empdept = new_empdetails[1]
    self.emp_name = new_empname
    self.emp_dept = new_empdept
          

#   def changeinfo(self, new_empname, new_empdept):
#       self.emp_name = new_empname
#       self.emp_dept = new_empdept
  
  @staticmethod
  def addition(x,y):
      print(x+y)

  @classmethod
  def chnageInClass(cls, new_company):
      cls.company_name = new_company
    
emp1 = employee("onkar" , "IT")

emp1.info = ["Priyaa", "HR"]

print(emp1.info)
