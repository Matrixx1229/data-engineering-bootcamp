# %% [markdown]
# ### UNION and  UNION BYNAME

# %% [markdown]
# ### Preparing Dataframes

# %%
data1 = [('1','kad'),
        ('2','sid')]
schema1 = 'id STRING, name STRING' 

df1 = spark.createDataFrame(data1,schema1)

data2 = [('3','rahul'),
        ('4','jas')]
schema2 = 'id STRING, name STRING' 

df2 = spark.createDataFrame(data2,schema2)

# %%
df1.display()
df2.display()

# %%
# Union

df1.union(df2).display()

# %%
data1 = [('kad','1',),
        ('sid','2',)]
schema1 = 'name STRING, id STRING' 

df1 = spark.createDataFrame(data1,schema1)

df1.display()

# %%
df1.union(df2).display()
df1.unionByName(df2).display()

# %% [markdown]
# ## String Functions
# ### Initcap()

# %%
df = (
    spark.read.format("csv")
    .option("inferSchema", True)
    .option("header", True)
    .load("/Volumes/dataxbootcamp/default/datax/BigMart Sales.csv")
)

df.display()

# %%
from pyspark.sql.types  import *
from pyspark.sql.functions import *

# %%
df.select(initcap('Item_Type').alias('upper_Item_type')).display()

# %% [markdown]
# ## Date Functions
# ### Current_Date

# %%
df = df.withColumn('curr_date', current_date())
df.display()

# %%
# Date_Add()

df = df.withColumn('week_after', date_add('curr_date', 7))
df.display()

# %%
# Date_Sub()
df = df.withColumn('week_before', date_sub('curr_date', 7))
df.display()

# %%
# DateDIFF
df = df.withColumn('datediff',datediff('week_after','curr_date'))

df.display()

# %%
# Date_Format()

df = df.withColumn('week_before',date_format('week_before','dd-MM-yyyy'))

df.display()

# %% [markdown]
# ## Handling Nulls
# ### Dropping NUlls

# %%
df.dropna("all").display()

# %%
df.dropna('any').display()

# %%
df.dropna(subset=['Outlet_Size']).display()

# %% [markdown]
# ## Filling Nulls

# %%
df.fillna('Not Available').display()

# %%
df.fillna('NotAvailable',subset=['Outlet_Size']).display()

# %% [markdown]
# ## SPLIT and Indexing

# %%
# SPLIT

df.withColumn('Outlet_Type', split('Outlet_Type', ' ')).display()

# %%
# Indexing

df.withColumn('Outlet_Type', split('Outlet_Type', ' ')[1]).display()

# %%
# Explode

df_exp = df.withColumn('Outlet_Type', split('Outlet_Type', ' '))
df_exp.display()

# %%
df_exp.withColumn('Outlet_Type', explode('Outlet_Type')).display()

# %%
df_exp.withColumn('type1_flag', array_contains('Outlet_Type', 'Type1')).display()

# %% [markdown]
# ## Group_BY

# %%
df.display()

# %%
# scene - 1

df.groupBy('Item_Type').agg(sum('Item_MRP')).display()

# %%
# scene - 2 
df.groupBy('Item_Type').agg(avg('Item_MRP')).display()

# %%
# scene - 3

df.groupBy('Item_Type', 'Outlet_Type').agg(sum('Item_MRP')).alias('Item_MRP').display()

# %%
# scene - 4

df.groupBy('Item_Type', 'Outlet_Type').agg(sum('Item_MRP').alias('SUM'), avg('Item_MRP').alias('Total_MRP')).display()
