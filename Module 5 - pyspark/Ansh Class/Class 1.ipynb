# %% [markdown]
# # Data Reading

# %% [markdown]
# ### data reading in json

# %%
df_json = (
    spark.read.format("csv")
    .option("InferSchema", True)
    .option("header", True)
    .option("multiline", False)
    .load("/Volumes/dataxbootcamp/default/datax/BigMart Sales.csv")
)
df.write.mode("overwrite").json(
    "/Volumes/dataxbootcamp/default/datax/BigMart_Sales_JSON"
)

# %%
df_json = (
    spark.read.format("json")
    .option("inferSchema", True)
    .load("/Volumes/dataxbootcamp/default/datax/BigMart_Sales_JSON")
)

df_json.display()

# %% [markdown]
# ### Data Reading Utils

# %%
dbutils.fs.ls("dbfs:/Volumes/dataxbootcamp/default/datax/")

# %%
df = (
    spark.read.format("csv")
    .option("inferSchema", True)
    .option("header", True)
    .load("/Volumes/dataxbootcamp/default/datax/BigMart Sales.csv")
)

df.display()

# %% [markdown]
# ## Schema Definition

# %%
df.printSchema()

# %% [markdown]
# DDL Schema

# %%
my_ddl_schema = """
                    Item_Identifier STRING,
                    Item_Weight STRING,
                    Item_Fat_Content STRING, 
                    Item_Visibility DOUBLE,
                    Item_Type STRING,
                    Item_MRP DOUBLE,
                    Outlet_Identifier STRING,
                    Outlet_Establishment_Year INT,
                    Outlet_Size STRING,
                    Outlet_Location_Type STRING, 
                    Outlet_Type STRING,
                    Item_Outlet_Sales DOUBLE 

            """

# %%
df = (
    spark.read.format("csv")
    .schema(my_ddl_schema)
    .load("/Volumes/dataxbootcamp/default/datax/BigMart Sales.csv")
)

# %%
df.display()

# %%
df.printSchema()

# %% [markdown]
# ### StructType() Schema

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %% [markdown]
# ## SELECT

# %%
df.select("Item_Identifier", "Item_Weight","Item_Fat_Content",).display()

# %% [markdown]
# ## ALIAS

# %%
df.select(col('Item_Identifier').alias('Item_ID')).display()

# %%
df = (
    spark.read.format("csv")
    .option("inferSchema", True)
    .option("header", True)
    .load("/Volumes/dataxbootcamp/default/datax/BigMart Sales.csv")
)

df.display()

# %% [markdown]
# ## FILTER

# %% [markdown]
# SCENE - 1

# %%
df.filter(col('Item_Fat_Content') == 'Regular').display()

# %% [markdown]
# SCENE - 2

# %%
ds = df.filter((col('Item_Weight')<10) & (col('Item_Type') == "Soft Drinks"))
display(ds)

# %% [markdown]
# SCENE - 3

# %%
df.filter((col('Outlet_Size').isNull()) & (col('Outlet_Location_Type').isin('Tier 1','Tier 2'))).display()
